# %% [markdown]
# <a href="https://colab.research.google.com/github/kkettip/datasci_4_web_viz/blob/main/datasci_4_web_viz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
url = 'https://raw.githubusercontent.com/kkettip/datasci_4_web_viz/main/Datasets/PLACES__Local_Data_for_Better_Health__County_Data_2023_release%20%20CT.csv'
df = pd.read_csv(url)
df
# Out:
#      Year StateAbbr    StateDesc LocationName DataSource         Category  \
# 0    2021        CT  Connecticut    New Haven      BRFSS       Disability
# 1    2021        CT  Connecticut   New London      BRFSS  Health Outcomes
# 2    2020        CT  Connecticut      Tolland      BRFSS       Prevention
# 3    2021        CT  Connecticut   New London      BRFSS       Prevention
# 4    2021        CT  Connecticut   New London      BRFSS  Health Outcomes
# ..    ...       ...          ...          ...        ...              ...
# 587  2021        CT  Connecticut      Windham      BRFSS       Prevention
# 588  2021        CT  Connecticut    Middlesex      BRFSS  Health Outcomes
# 589  2021        CT  Connecticut   New London      BRFSS       Disability
# 590  2021        CT  Connecticut    Middlesex      BRFSS       Disability
# 591  2020        CT  Connecticut      Windham      BRFSS       Prevention
#
#                                                Measure Data_Value_Unit  \
# 0     Mobility disability among adults aged >=18 years               %
# 1              Depression among adults aged >=18 years               %
# 2    Visits to dentist or dental clinic among adult...               %
# 3    Cholesterol screening among adults aged >=18 y...               %
# 4                  Stroke among adults aged >=18 years               %
# ..                                                 ...             ...
# 587  Cholesterol screening among adults aged >=18 y...               %
# 588             Arthritis among adults aged >=18 years               %
# 589    Hearing disability among adults aged >=18 years               %
# 590        Any disability among adults aged >=18 years               %
# 591  Fecal occult blood test, sigmoidoscopy, or col...               %
#
#              Data_Value_Type  Data_Value  ...  Low_Confidence_Limit  \
# 0           Crude prevalence        12.0  ...                  10.2
# 1           Crude prevalence        21.6  ...                  18.7
# 2           Crude prevalence        72.6  ...                  69.4
# 3    Age-adjusted prevalence        87.4  ...                  84.9
# 4           Crude prevalence         3.0  ...                   2.6
# ..                       ...         ...  ...                   ...
# 587         Crude prevalence        87.4  ...                  84.8
# 588         Crude prevalence        26.7  ...                  23.5
# 589         Crude prevalence         6.9  ...                   6.1
# 590         Crude prevalence        23.6  ...                  20.1
# 591  Age-adjusted prevalence        77.2  ...                  74.4
#
#      High_Confidence_Limit  TotalPopulation  LocationID  CategoryID  \
# 0                     14.2           863700        9009     DISABLT
# 1                     24.9           268805        9011     HLTHOUT
# 2                     75.5           150293        9013     PREVENT
# 3                     89.7           268805        9011     PREVENT
# 4                      3.4           268805        9011     HLTHOUT
# ..                     ...              ...         ...         ...
# 587                   89.7           116418        9015     PREVENT
# 588                   29.7           164759        9007     HLTHOUT
# 589                    7.9           268805        9011     DISABLT
# 590                   27.2           164759        9007     DISABLT
# 591                   80.0           116418        9015     PREVENT
#
#         MeasureId DataValueTypeID          Short_Question_Text  \
# 0        MOBILITY          CrdPrv          Mobility Disability
# 1      DEPRESSION          CrdPrv                   Depression
# 2          DENTAL          CrdPrv                 Dental Visit
# 3      CHOLSCREEN       AgeAdjPrv        Cholesterol Screening
# 4          STROKE          CrdPrv                       Stroke
# ..            ...             ...                          ...
# 587    CHOLSCREEN          CrdPrv        Cholesterol Screening
# 588     ARTHRITIS          CrdPrv                    Arthritis
# 589       HEARING          CrdPrv           Hearing Disability
# 590    DISABILITY          CrdPrv               Any Disability
# 591  COLON_SCREEN       AgeAdjPrv  Colorectal Cancer Screening
#
#                         Geolocation Counties
# 0    POINT (-72.9002033 41.3497185)     1044
# 1    POINT (-72.1086339 41.4726517)     1045
# 2    POINT (-72.3409779 41.8580807)       38
# 3    POINT (-72.1086339 41.4726517)     1045
# 4    POINT (-72.1086339 41.4726517)     1045
# ..                              ...      ...
# 587  POINT (-71.9907017 41.8249987)       39
# 588  POINT (-72.5227802 41.4330028)     1043
# 589  POINT (-72.1086339 41.4726517)     1045
# 590  POINT (-72.5227802 41.4330028)     1043
# 591  POINT (-71.9907017 41.8249987)       39
#
# [592 rows x 22 columns]

# %%
df.columns
# Out:
# Index(['Year', 'StateAbbr', 'StateDesc', 'LocationName', 'DataSource',
#        'Category', 'Measure', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value', 'Data_Value_Footnote_Symbol', 'Data_Value_Footnote',
#        'Low_Confidence_Limit', 'High_Confidence_Limit', 'TotalPopulation',
#        'LocationID', 'CategoryID', 'MeasureId', 'DataValueTypeID',
#        'Short_Question_Text', 'Geolocation', 'Counties'],
#       dtype='object')

# %%
# Filter for 'OBESITY' as measureid and 'Age-adjusted prevalence' as data_value_type
df = df[(df['MeasureId'] == 'OBESITY') & (df['Data_Value_Type'] == 'Age-adjusted prevalence')]
df
# Out:
#      Year StateAbbr    StateDesc LocationName DataSource         Category  \
# 220  2021        CT  Connecticut     Hartford      BRFSS  Health Outcomes
# 323  2021        CT  Connecticut    Middlesex      BRFSS  Health Outcomes
# 343  2021        CT  Connecticut      Windham      BRFSS  Health Outcomes
# 416  2021        CT  Connecticut    New Haven      BRFSS  Health Outcomes
# 451  2021        CT  Connecticut   Litchfield      BRFSS  Health Outcomes
# 462  2021        CT  Connecticut      Tolland      BRFSS  Health Outcomes
# 537  2021        CT  Connecticut    Fairfield      BRFSS  Health Outcomes
# 541  2021        CT  Connecticut   New London      BRFSS  Health Outcomes
#
#                                   Measure Data_Value_Unit  \
# 220  Obesity among adults aged >=18 years               %
# 323  Obesity among adults aged >=18 years               %
# 343  Obesity among adults aged >=18 years               %
# 416  Obesity among adults aged >=18 years               %
# 451  Obesity among adults aged >=18 years               %
# 462  Obesity among adults aged >=18 years               %
# 537  Obesity among adults aged >=18 years               %
# 541  Obesity among adults aged >=18 years               %
#
#              Data_Value_Type  Data_Value  ...  Low_Confidence_Limit  \
# 220  Age-adjusted prevalence        33.4  ...                  29.4
# 323  Age-adjusted prevalence        31.0  ...                  26.4
# 343  Age-adjusted prevalence        35.3  ...                  29.9
# 416  Age-adjusted prevalence        31.4  ...                  27.4
# 451  Age-adjusted prevalence        26.9  ...                  22.6
# 462  Age-adjusted prevalence        29.1  ...                  24.5
# 537  Age-adjusted prevalence        24.9  ...                  21.3
# 541  Age-adjusted prevalence        31.0  ...                  26.5
#
#      High_Confidence_Limit  TotalPopulation  LocationID  CategoryID  \
# 220                   38.1           896854        9003     HLTHOUT
# 323                   35.8           164759        9007     HLTHOUT
# 343                   40.9           116418        9015     HLTHOUT
# 416                   36.4           863700        9009     HLTHOUT
# 451                   31.4           185000        9005     HLTHOUT
# 462                   33.7           150293        9013     HLTHOUT
# 537                   28.8           959768        9001     HLTHOUT
# 541                   36.1           268805        9011     HLTHOUT
#
#      MeasureId DataValueTypeID Short_Question_Text  \
# 220    OBESITY       AgeAdjPrv             Obesity
# 323    OBESITY       AgeAdjPrv             Obesity
# 343    OBESITY       AgeAdjPrv             Obesity
# 416    OBESITY       AgeAdjPrv             Obesity
# 451    OBESITY       AgeAdjPrv             Obesity
# 462    OBESITY       AgeAdjPrv             Obesity
# 537    OBESITY       AgeAdjPrv             Obesity
# 541    OBESITY       AgeAdjPrv             Obesity
#
#                         Geolocation Counties
# 220  POINT (-72.7329157 41.8060534)     1041
# 323  POINT (-72.5227802 41.4330028)     1043
# 343  POINT (-71.9907017 41.8249987)       39
# 416  POINT (-72.9002033 41.3497185)     1044
# 451  POINT (-73.2354042 41.7918833)     1042
# 462  POINT (-72.3409779 41.8580807)       38
# 537  POINT (-73.3670614 41.2274128)     1040
# 541  POINT (-72.1086339 41.4726517)     1045
#
# [8 rows x 22 columns]

# %%
# Group by 'LocationName' and get the average (or sum) 'Data_Value'
grouped = df.groupby('LocationName').Data_Value.mean().sort_values(ascending=False)
grouped
# Out:
# LocationName
# Windham       35.3
# Hartford      33.4
# New Haven     31.4
# Middlesex     31.0
# New London    31.0
# Tolland       29.1
# Litchfield    26.9
# Fairfield     24.9
# Name: Data_Value, dtype: float64

# %%
# Plotting
plt.figure(figsize=(10, 7))
grouped.plot(kind='bar', color='lightcoral')
plt.ylabel('Average Data Value (Age-adjusted prevalence) - Percent')
plt.xlabel('Location (County)')
plt.title('Obesity Age-adjusted Prevalence by County in CT')
plt.xticks(rotation=90)
plt.tight_layout()
plt.savefig("obesity_per_location.png")  # Saving the plot as an image
plt.show()

# %%
import ipywidgets as widgets

# Compute the average data value across all counties
avg_data_value = df['Data_Value'].mean()

# Sort the counties in ascending order for the dropdown list
sorted_counties = sorted(df['LocationName'].unique())

# Interactive selection of county for visualization using ipywidgets
@widgets.interact(County=sorted_counties)
def plot_data(County):
    county_value = df[df['LocationName'] == County]['Data_Value'].values[0]

    # Labels for bars
    labels = [County, 'Average across all counties']

    # Data values for bars
    values = [county_value, avg_data_value]

    plt.figure(figsize=(8, 6))

    # Plot the bars
    colors = ['lightcoral', 'lightblue']
    plt.bar(labels, values, color=colors)

    plt.ylabel('Data Value (Age-adjusted prevalence) - Percent')
    plt.title(f'Obesity Age-adjusted Prevalence in {County} vs Average across all counties')

    plt.tight_layout()
    plt.show()
# Out:
# interactive(children=(Dropdown(description='County', options=('Fairfield', 'Hartford', 'Litchfield', 'Middlese…
